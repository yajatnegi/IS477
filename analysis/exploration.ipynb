# %% [markdown]
# # Exploratory Analysis Notebook
# Draft notebook for Milestone 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
print('Notebook initialized.')

# %%
# Load cleaned datasets
zhvi = pd.read_csv('../data/cleaned/ZHVI_cleaned.csv')
income = pd.read_csv('../data/cleaned/Income_cleaned.csv')
zhvi.head(), income.head()

# %%
# Load merged dataset
merged = pd.read_csv('../data/final/combined.csv')
merged.head()

# %%
# Quick summary
merged[['zhvi', 'median_income']].describe()

# %%
# Correlation
merged[['zhvi', 'median_income']].corr()

# %%
# Scatterplot
plt.figure(figsize=(7,5))
plt.scatter(merged['median_income'], merged['zhvi'], alpha=0.5)
plt.xlabel('Median Household Income')
plt.ylabel('ZHVI (Home Value)')
plt.title('Income vs Home Value – Draft')
plt.show()
